# %%
print("hello world")
# Out:
# hello world

# %%
#shift+enter--->New cell create and code run
#ctrl+enter----->only code run

# %%
num=10
print(type(num))
# Out:
# <class 'int'>

# %%
num1=input("enter the number")
print(type(num1))
# Out:
# <class 'str'>

# %%
num2=input('enter the number')
num3=input("enter the number")
print(type(num2))
print(type(num3))
# Out:
# <class 'str'>
# <class 'str'>

# %%
num1=input("enter the number1;")
num2=input("enter the number2;")
print(num1)
print(num2)
print(type(num1))
print(type(num2))
# Out:
# 10
# 20
# <class 'str'>
# <class 'str'>

# %%
num1=10
print(type(num1))
# Out:
# <class 'int'>

# %%
num1=float(input("enter the number"))
print(type(num1))
# Out:
# <class 'float'>

# %%
name=input("enter the name;")
print(type(name))
# Out:
# <class 'str'>

# %%
num1=float(input("enter the number"))
print(int(num1))
# Out:
# 10

# %%
num3=5+6j
print(type(num3))
# Out:
# <class 'complex'>

# %%
num1=10
print(str(num1))
# Out:
# 10

# %%
num2=int(input("enter the number"))
print(type(str(num2)))
print(str(num2))
# Out:
# <class 'str'>
# 10

# %%
name=input("enter the name")
print(int(name))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 2
#       1 name=input("enter the name")
# ----> 2 print(int(name))
#
# ValueError: invalid literal for int() with base 10: 'anu'

# %%
name="10"
print(int(name))
# Out:
# 10
